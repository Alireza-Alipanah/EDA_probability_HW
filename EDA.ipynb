# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<div align=center>
# 			<font face="IranNastaliq" size=30>
# 				<p></p>
# 				<p></p>
# به نام خدا
# 				<p></p>
# 			</font>
# 			<font color=#FF7500>
# دانشگاه صنعتی شریف - دانشکده مهندسی کامپیوتر
#             </font>
# 			<p></p>
# 			<font color=blue>
# آمار و احتمال مهندسی
#             </font>
# 			<br />
# 			<br />
# Spring 1401        </div>
# 		<hr/>
# 		<font color=red size=6>
# 			<br />
# 			<div align=center>
# EDA (Exploratory Data Analysis)
#             </div>
# 		</font>
# 		<br />
# 		<div align=center>
# Alireza noroozi
#         </div>
# 	</font>
# </div>

# %% [markdown]
# Alireza Alipanah<br>
# 99106396

# %% [markdown]
# # Warm-up

# %% [markdown]
# with 'salaries' data that is about proffessors income, we have plotted these pictures, now you should retrival the R code of these plots and speak a few words about what you see and understand from them.

# %%
# your code goes here
library(ggplot2)
data <- read.csv("./datasets/Salaries.csv")
ggplot(data) +
geom_point(aes(x = yrs.service, y = salary, shape = sex, colour = rank))
ggplot(data, aes(x = yrs.service, y = salary)) + 
geom_point(colour = "white", size = 3) +
geom_point(aes(colour = rank), size = 1)
# Out:
# plot without title
# plot without title

# %% [markdown]
# From the Graphs we can derive the following informations:<ul>
# <li>Professors usually have higher salary than Associate Professors and Assistant Professor regardless of the years in service.</li>
# <li>Associate Professors usually have higher salary than Assistant Professor regardless of the years in service.</li>
# <li>Males dominate Both the highest paying and lowest paying salaries while females salaries are closer to the mean and have less variance</li></ul>

# %% [markdown]
# <div id="sec_t1" style="direction:rtl;line-height:300%;">
#         <img src="figs/Rplot2.png" style="float:center; width:60%"/>
#         <br>
#         <img src="figs/Rplot1.png" style="float:center; width:60%;"/>
# </div>

# %% [markdown]
# Exploratory Data Analysis refers to the critical process of performing initial investigations on data so as to discover patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and graphical representations.
# It is a good practice to understand the data first and try to gather as many insights from it. EDA is all about making sense of data in hand,before getting them dirty with it.

# %% [markdown]
# <div id="sec_t1" style="direction:rtl;line-height:300%;">
#         <img src="figs/The-fundamental-steps-of-the-exploratory-data-analysis-process.png" style="float:center; width:60%"/>
#
# </div>

# %% [markdown]
# Read the dataset and show 10 first row of it.

# %%
# your code goes here
data <- read.csv("./datasets/bike_buyers_na.csv")

# %% [markdown]
# call summary function on data and see what you can understand from the output and explain about difference between categorical and numerical data column.

# %%
# your code goes here
summary(data)
# Out:
#        X                ID        Marital.Status        Gender
#  Min.   :   1.0   Min.   :11000   Length:1000        Length:1000
#  1st Qu.: 250.8   1st Qu.:15291   Class :character   Class :character
#  Median : 500.5   Median :19744   Mode  :character   Mode  :character
#  Mean   : 500.5   Mean   :19966
#  3rd Qu.: 750.2   3rd Qu.:24471
#  Max.   :1000.0   Max.   :29447
#
#      Income          Children      Education          Occupation
#  Min.   : 10000   Min.   :0.000   Length:1000        Length:1000
#  1st Qu.: 30000   1st Qu.:0.000   Class :character   Class :character
#  Median : 60000   Median :2.000   Mode  :character   Mode  :character
#  Mean   : 56290   Mean   :1.908
#  3rd Qu.: 70000   3rd Qu.:3.000
#  Max.   :170000   Max.   :5.000
#                   NA's   :18
#   Home.Owner             Cars       Commute.Distance      Region
#  Length:1000        Min.   :0.000   Length:1000        Length:1000
# ...

# %% [markdown]
# If we look at income, we can see the following values:
# <ul>
#     <li>25% of the population made less than 30.</li>
#     <li>25% of the population made between 30k and 60k.</li>
#     <li>25% of the population made between 60k and 70k.</li>
#     <li>25% of the population made between 70k and 170k.</li>
# </ul>
# since 25% of the population made between 60k and 70k which has the smallest interval for salary, we can predicate that this group is most likely to buy a bike.<br>
# since $mean - min = 50k$ and $max - mean = 110k$ we can guess that people with less salaries than mean are more likely to buy a bike.<br>
# if we look at children, we can see the following values:
# <ul>
#     <li>25% of the population are childless.</li>
#     <li>25% of the population have between zero and 2 children.</li>
#     <li>25% of the population have between 2 and 3 children.</li>
#     <li>25% of the population have between 3 and 5 children</li>
# </ul>
# since 25% of the population have no child, it is obvious that people with no children have much higher likelihood of buying a bike, while people with more than 3 chidlren have the least desire to buy a bike.<br>
# with the mean of 1.9, and min of 0 and max of 5, one can guess that poeple with less child are more likely to buy a bike.<br>
# if we look at cars, we can see the following values:
# <ul>
#     <li>25% of the population have between 0 and 1 car.</li>
#     <li>25% of the population have between 1 and 1.228 cars.</li>
#     <li>25% of the population have between 1.228 and 2 cars.</li>
#     <li>25% of the population have between 2 and 4 cars</li>
# </ul>
# looking at the data we see the people who fall between 1'st and 2'nd Qu are most likely to buy a bike.<br>
# with the mean of 1.455 cars, it is reasonable to assume that people that have fewer cars are more likely to buy a bike<br>
# if we look at age, we can see the following values:
# <ul>
#     <li>25% of the population are between 25 and 35.</li>
#     <li>25% of the population are between 35 and 43.</li>
#     <li>25% of the population are between 43 and 52.</li>
#     <li>25% of the population are between 52 and 89</li>
# </ul>
# looking at the length of interval it could be said that people between 35 and 52 are more likely to buy a bike.<br>

# %% [markdown]
# # dealing with NA's

# %% [markdown]
# In R, NA stands for Not Available. Each cell of your data that displays NA is a missing value. there are several ways for dealing with them, like omit those rows or fill them with relative data's like mean or zero or median.
# now in this part we want you to fill na values of column 'car' with median and other columns with mean and call summary function again.

# %%
# your code goes here
replace <- function (vec, func) {
    m <- func(vec, na.rm = TRUE)
    na.s <- is.na(vec)
    vec[na.s] <- m
    return(vec)
}
data$Cars <- replace(data$Cars, mean)
data$Children <- replace(data$Children, median)

# %% [markdown]
# # different plots, which plot for wich column?
# for each plot choose propper features and draw each plot.
# ## Bar Plot
# A bar plot is a plot that presents categorical data with rectangular bars with lengths proportional to the values that they represent. A bar plot shows comparisons among discrete categories. One axis of the plot shows the specific categories being compared, and the other axis represents a measured value.

# %%
# your code goes here
ggplot(data) + geom_bar(aes(x = Commute.Distance))
ggplot(data) + geom_bar(aes(x = Region))
ggplot(data) + geom_bar(aes(x = Gender))
ggplot(data) + geom_bar(aes(x = Marital.Status))
ggplot(data) + geom_bar(aes(x = Occupation))
ggplot(data) + geom_bar(aes(x = Purchased.Bike))
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ## Scatter Plot
# A scatter plot uses dots to represent values for two different numeric variables. The position of each dot on the horizontal and vertical axis indicates values for an individual data point. Scatter plots are used to observe relationships between variables.

# %%
# your code goes here
ggplot(data) + geom_point(aes(x = Age, y = Income))
ggplot(data) + geom_point(aes(x = Age, y = Children))
ggplot(data) + geom_point(aes(x = Age, y = Cars))
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ## Histogram
# A histogram is a graphical display of data using bars of different heights. In a histogram, each bar groups numbers into ranges. Taller bars show that more data falls in that range. A histogram displays the shape and spread of continuous sample data.

# %%
# your code goes here
ggplot(data) + geom_histogram(aes(x = Age), bins = 30)
# Out:
# plot without title

# %% [markdown]
# ## Density Plot
# A density plot is a representation of the distribution of a numeric variable. It uses a kernel density estimate to show the probability density function of the variable
# . It is a smoothed version of the histogram and is used in the same concept.

# %%
# your code goes here
ggplot(data) + geom_density(aes(x = Children))
ggplot(data) + geom_density(aes(x = Income))
# Out:
# plot without title
# plot without title

# %% [markdown]
# ## Trend Plot
# Trend plots are used to illustrate how a random variable may change over time (e.g. sales, exchange rates, stick prices). In order to create a Trend plot one must first have defined a set of cells as an input or output array.

# %%
# your code goes here
ggplot(data, aes(x = Age, y = log(Income) / Age)) + geom_point() + geom_line() + geom_smooth()
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %% [markdown]
# # Extra point but main assignment:)
# now it is your turn to do eda on the salaries dataset or bike-buyers, ask proper statistic questions and answer them with nice plots.

# %% [markdown]
# you should use visualisation and transformation to explore your data in a systematic way, a task that statisticians call exploratory data analysis, or EDA for short. EDA is an iterative cycle. You:
#
# 1 )Generate questions about your data.
#
# 2 ) Search for answers by visualising, transforming, and modelling your data.
#
# 3 ) Use what you learn to refine your questions and/or generate new questions.
#
# EDA is not a formal process with a strict set of rules. More than anything, EDA is a state of mind. During the initial phases of EDA you should feel free to investigate every idea that occurs to you. Some of these ideas will pan out, and some will be dead ends. As your exploration continues, you will home in on a few particularly productive areas that you’ll eventually write up and communicate to others.
#
# EDA is an important part of any data analysis, even if the questions are handed to you on a platter, because you always need to investigate the quality of your data. Data cleaning is just one application of EDA: you ask questions about whether your data meets your expectations or not. To do data cleaning, you’ll need to deploy all the tools of EDA: visualisation, transformation, and modelling.

# %%
# your code goes here
df <- read.csv("./datasets/Salaries.csv")

# %%
summary(df)
# Out:
#        X           rank            discipline        yrs.since.phd
#  Min.   :  1   Length:397         Length:397         Min.   : 1.00
#  1st Qu.:100   Class :character   Class :character   1st Qu.:12.00
#  Median :199   Mode  :character   Mode  :character   Median :21.00
#  Mean   :199                                         Mean   :22.31
#  3rd Qu.:298                                         3rd Qu.:32.00
#  Max.   :397                                         Max.   :56.00
#   yrs.service        sex                salary
#  Min.   : 0.00   Length:397         Min.   : 57800
#  1st Qu.: 7.00   Class :character   1st Qu.: 91000
#  Median :16.00   Mode  :character   Median :107300
#  Mean   :17.61                      Mean   :113706
#  3rd Qu.:27.00                      3rd Qu.:134185
#  Max.   :60.00                      Max.   :231545

# %%
ggplot(df) + geom_bar(aes(x = rank))
ggplot(df) + geom_bar(aes(x = sex))
# Out:
# plot without title
# plot without title

# %% [markdown]
# from the above graph we can deduce the following information:
# <ul>
#     <li>We have a lot more professors in the dataset than Associate Professors and Assistant Professors.</li>
#     <li>The number of Associate Professors and Assistant Professors are close.</li>
#     <li>We seem to have a little more data for the B displine</li>
#     <li>We have a lot more Males in the dataset compared to Females.</li>
# </ul>

# %%
ggplot(df, aes(x = rank, y = salary)) + geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# we can clearly see from the above graph that Professors on average make much more money than the other groups and also have a wider reange of salary. followed by Professors, Associate Proffessors are the second in terms of salary, their salary also has a wider range compared to Assistant Professors.

# %%
ggplot(df, aes(x = sex, y = salary)) + geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# from the above graph we can see the following information:
# <ul>
#     <li>Females make almost as much as Males, albeit a little less.</li>
#     <li>The highest paid people are all Male.</li>
# </ul>

# %%
ggplot(df, aes(x = yrs.since.phd, y = salary)) + geom_point(alpha = 0.5) + geom_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# It appears that the salary increases linearly with the years since phd, though one thig to note is that the variance increases as well.

# %%
ggplot(df, aes(x = yrs.service, y = salary)) + geom_point(alpha = 0.5) + geom_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# Following the years since phd, salary may increase as the years in service inreaces, although this should be subject to further investigation since there is a very high variance in data

# %%
ggplot(df, aes(x = discipline, y = salary)) + geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# Looking at disciplines, it appears that B discipline makes a little more on average, it also has the highest paying individual as well.

# %% [markdown]
# In conclusion from the above graph we can note the following:
# <ul>
#     <li>On average, Professors make the highest amount of money, which are followed by Associate Professor, Assistant Professors make the least.</li>
#     <li>Males dominate the highest paying positions.</li>
#     <li>On average, Females make a little less than Males.</li>
#     <li>salary seems to increase as the years since PHD increases.</li>
#     <li>On average, B discipline individuals make more money than their A discipline counterparts.</li>
# </ul>
# Now we could ask the following questions:
# <ul>
#     <li>Is the mean of Female salary, a little less compared to Males when Professors, Associate Professors and Assistant Professors are seperated?</li>
#     <li>How about the above question when disciplines are seperated?</li>
#     <li>Does the increase of years since PHD affect have the same effect on the salaries of both Male and Female?</li>
# </ul>

# %%
ggplot(df, aes(x = sex, y = salary)) + geom_boxplot() + facet_wrap(~ rank)
# Out:
# plot without title

# %% [markdown]
# For professors:
# <ul>
#     <li>Mean salary for males is relatively close to Females.</li>
#     <li>Males have a much wider range of salary.</li>
#     <li>both the highest paying and the lowest paying jobs are dominated by Males.</li>
#     <li>Females have much lower variance compared to Males.</li>
# </ul>
# For Associate Professors:
# <ul>
#     <li>There seems to be a meaningful difference between Male and Female mean salary.</li>
#     <li>the highest paying jobs seems to be for Males.</li>
#     <li>Females have the lowest paying jobs.</li>
# </ul>
# For Assistance Professors:
# <ul>
#     <li>There seems to be a meaningful difference between Male and Female mean salary.</li>
#     <li>Females have the highest payin job, but this could be an outlier since around 50% of Males get paid more than almost all of Females.</li>
#     <li>Males seems to have a big variance whilst the Females variance appears to be small.</li>
# </ul>

# %%
ggplot(df, aes(x = sex, y = salary)) + geom_boxplot() + facet_wrap(~ discipline)
# Out:
# plot without title

# %% [markdown]
# For A discipline:
# <ul>
#     <li>There is a big difference between male and Female mean salary.</li>
#     <li>Males hold both the highest and lowest paying positions.</li>
#     <li>The second qu has a relatively small range</li>
#     <li>males seems to have a much higher variance compared to women.</li>
# </ul>
# For B discipline:
# <ul>
#     <li>Males seem to have a relatively higher mean salary compared to Femals.</li>
#     <li>the difference between lowest paying Males and Females seems rather small</li>
#     <li>Males hold the highest paying jobs and also have more variance</li>
# </ul>

# %%
ggplot(df, aes(x = yrs.since.phd, y = salary)) + geom_point(alpha = 0.5) + geom_smooth(method = "lm") + facet_wrap(~ sex)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# As said before, the salary seems to increase with the years since phd.<br>
# Although Females have a sharper increase rate, this could be due to lack of sufficient data as such there doesnt seem to be any meaningful difference for the increase of salary between Males Females<br>
# It appears that rank and discipline are the two features for which salary seems to differ considerably between Males and Females. We no investigate to see if these features are dependant.

# %%
ggplot(df) + geom_raster(aes(x = rank, y = discipline, fill = salary)) + labs(title = "Males and Females")
ggplot(df) + geom_raster(aes(x = rank, y = discipline, fill = salary)) + facet_wrap(~ sex)
# Out:
# plot without title
# plot without title

# %%
ggplot(df[df$discipline == "A", ]) + geom_boxplot(aes(x = sex, y = salary)) + facet_wrap(~ rank) + labs(title = "A Discipline")
ggplot(df[df$discipline == "B", ]) + geom_boxplot(aes(x = sex, y = salary)) + facet_wrap(~ rank) + labs(title = "B Discipline")
# Out:
# plot without title
# plot without title

# %% [markdown]
# As we can see from the graphs, there seems to be huge differences in the distribution of salaries with different combinations of rank and discipline.<br>
# All in all we can conclude that our dataset has the followibng characteristis:
# <ul>
#     <li>salaries seem to increase regardless of gender with increase in years since PHD.</li>
#     <li>there my be a connection between increase in salary and increase in years in service, but this property should be investigated further beacause of high variance in data</li>
#     <li>different combinations of ranks and disciplines seem to result in different distribution of salaries.</li>
#     <li>sex, rank, and discipline seem to be the three defining factors for salary.</li>
# </ul>
